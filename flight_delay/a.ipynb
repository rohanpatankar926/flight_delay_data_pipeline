# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("FlightDelayPrediction").getOrCreate()
data=spark.read.option("header","true").csv("data/2011.csv")
data1=spark.read.option("header","true").csv("data/2012.csv")
data=data.union(data1)
len(data.columns)
# Out:
# 28

# %%
data.isna().sum()
# Out:
# FL_DATE                    0
# OP_CARRIER                 0
# OP_CARRIER_FL_NUM          0
# ORIGIN                     0
# DEST                       0
# CRS_DEP_TIME               0
# DEP_TIME                 353
# DEP_DELAY                353
# TAXI_OUT                 360
# WHEELS_OFF               360
# WHEELS_ON                373
# TAXI_IN                  373
# CRS_ARR_TIME               0
# ARR_TIME                 373
# ARR_DELAY                402
# CANCELLED                  0
# CANCELLATION_CODE      29633
# DIVERTED                   0
# CRS_ELAPSED_TIME           0
# ACTUAL_ELAPSED_TIME      402
# AIR_TIME                 402
# DISTANCE                   0
# CARRIER_DELAY          21262
# WEATHER_DELAY          21262
# NAS_DELAY              21262
# SECURITY_DELAY         21262
# LATE_AIRCRAFT_DELAY    21262
# Unnamed: 27            30000
# dtype: int64

# %%
from datetime import datetime
data["ID"]=data.index.astype(str) 
data
# Out:
#           FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0      2010-01-01         MQ               4438    LGA  RDU          1940
# 1      2010-01-01         MQ               4440    DCA  JFK           950
# 2      2010-01-01         MQ               4443    LGA  RDU           900
# 3      2010-01-01         MQ               4445    RDU  LGA          1940
# 4      2010-01-01         MQ               4447    JFK  DCA          2035
# ...           ...        ...                ...    ...  ...           ...
# 29995  2010-01-02         WN               3674    LAS  ONT          1925
# 29996  2010-01-02         WN               5752    LAS  ONT           950
# 29997  2010-01-02         WN                580    LAS  PDX          1940
# 29998  2010-01-02         WN               2796    LAS  PDX          1335
# 29999  2010-01-02         WN               5836    LAS  PDX           810
#
#        DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  ACTUAL_ELAPSED_TIME  \
# ...

# %%
import pandas as pd
data=pd.read_csv("/home/rohanpatankar/ml_prject_end_to_edn/flight_delay/flight_data_csv/part-00000-79ddd8aa-b4f2-4aad-afbc-5696232f6d88-c000.csv")
data.columns
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Unnamed: 27'],
#       dtype='object')
